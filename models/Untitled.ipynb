# %%
import numpy as np

# %%
import math
import torch
import torch.nn.functional as F
from torch import nn
from torchvision import models
# from utils.helpers import initialize_weights, set_trainable
from itertools import chain
import sys
sys.path.append("/mnt/batch/tasks/shared/LS_root/mounts/clusters/pyfuse/code/pyramid-fuse")
from Utils import *

# %%
class _PSPModule(nn.Module):
    def __init__(self, in_channels, bin_sizes, norm_layer):
        super(_PSPModule, self).__init__()
        out_channels = in_channels // len(bin_sizes)
        self.stages = nn.ModuleList([self._make_stages(in_channels, out_channels, b_s, norm_layer) 
                                                        for b_s in bin_sizes])
        self.bottleneck = nn.Sequential(
            nn.Conv2d(in_channels+(out_channels * len(bin_sizes)), out_channels, 
                                    kernel_size=3, padding=1, bias=False),
            norm_layer(out_channels),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.1)
        )

    def _make_stages(self, in_channels, out_channels, bin_sz, norm_layer):
        prior = nn.AdaptiveAvgPool2d(output_size=bin_sz)
        conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        bn = norm_layer(out_channels)
        relu = nn.ReLU(inplace=True)
        return nn.Sequential(prior, conv, bn, relu)
    
    def forward(self, features):
        h, w = features.size()[2], features.size()[3]
        pyramids = [features]
        pyramids.extend([F.interpolate(stage(features), size=(h, w), mode='bilinear', 
                                        align_corners=True) for stage in self.stages])
        output = self.bottleneck(torch.cat(pyramids, dim=1))
        return output

# %%
class PSPNet(nn.Module):
    def __init__(self, num_classes=21, use_aux=True):
        super(PSPNet, self).__init__()
        # TODO: Use synch batchnorm
        norm_layer = nn.InstanceNorm2d
#         model = getattr(resnet, backbone)(pretrained, norm_layer=norm_layer, )
#         m_out_sz = model.fc.in_features
        self.use_aux = use_aux 

#         self.initial = nn.Sequential(*list(model.children())[:4])
#         if in_channels != 3:
#             self.initial[0] = nn.Conv2d(in_channels, 64, kernel_size=7, stride=2, padding=3, bias=False)
#         self.initial = nn.Sequential(*self.initial)
        
#         self.layer1 = model.layer1
#         self.layer2 = model.layer2
#         self.layer3 = model.layer3
#         self.layer4 = model.layer4

        self.master_branch = nn.Sequential(
            _PSPModule(1024, bin_sizes=[1, 2, 3, 6], norm_layer=norm_layer),
            nn.Conv2d(1024//4, num_classes, kernel_size=1)
        )

        self.auxiliary_branch = nn.Sequential(
            nn.Conv2d(1024, 1024//2, kernel_size=3, padding=1, bias=False),
            norm_layer(1024//2),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.1),
            nn.Conv2d(1024//2, num_classes, kernel_size=1)
        )

#         initialize_weights(self.master_branch, self.auxiliary_branch)
#         if freeze_bn: self.freeze_bn()
#         if freeze_backbone: 
#             set_trainable([self.initial, self.layer1, self.layer2, self.layer3, self.layer4], False)

    def forward(self, x):
        input_size = (512, 1024)
        if x.shape[0]%6==0:
            input_size = (32*x.size()[2], 32*x.size()[3])
#         x = self.initial(x)
#         x = self.layer1(x)
#         x = self.layer2(x)
#         x_aux = self.layer3(x)
#         x = self.layer4(x_aux)
        x_aux = x
        output = self.master_branch(x)
        output = F.interpolate(output, size=input_size, mode='bilinear')
        output = output[:, :, :input_size[0], :input_size[1]]

        if self.training and self.use_aux:
            aux = self.auxiliary_branch(x_aux)
            aux = F.interpolate(aux, size=input_size, mode='bilinear')
            aux = aux[:, :, :input_size[0], :input_size[1]]
            return output
        return output

# %%
psp = PSPNet(21)

# %%
feat_equi = torch.randn([1, 1024, 16, 32])
feat_cube = torch.randn([6, 1024, 8, 8])

# %%
feat_equi = psp(feat_equi)
feat_cube = psp(feat_cube)
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))

# %%
feat_equi.shape
# Out:
# torch.Size([1, 21, 512, 1024])

# %%
feat_cube.shape
# Out:
# torch.Size([6, 21, 256, 256])

# %%
class CETransform(nn.Module):
    def __init__(self):
        super(CETransform, self).__init__()
        equ_h = [512, 128, 64, 32, 16]
        cube_h = [256, 64, 32, 16, 8]

        self.c2e = dict()
        self.e2c = dict()

        for h in equ_h:
            a = Equirec2Cube(1, h, h*2, h//2, 90)
            self.e2c['(%d,%d)' % (h, h*2)] = a

        for h in cube_h:
            a = Cube2Equirec(1, h, h*2, h*4)
            self.c2e['(%d)' % (h)] = a

    def E2C(self, x):
        print(x.shape)
        [bs, c, h, w] = x.shape
        key = '(%d,%d)' % (h, w)
        print(key)
        assert key in self.e2c
        return self.e2c[key].ToCubeTensor(x)

    def C2E(self, x):
        print(x.shape)
        [bs, c, h, w] = x.shape
        key = '(%d)' % (h)
        assert key in self.c2e and h == w
        return self.c2e[key].ToEquirecTensor(x)

    def forward(self, equi, cube):
        return self.e2c(equi), self.c2e(cube)

# %%
ce = CETransform()

# %%
feat_cube = feat_cube.cuda()

# %%
feat_cube = ce.C2E(feat_cube)
# Out:
# torch.Size([6, 21, 256, 256])
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/torch/nn/functional.py:2705: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "

# %%
feat_cube.shape
# Out:
# torch.Size([1, 21, 512, 1024])

# %%
feat_equi =  feat_equi.cuda()

# %%
feat_equi.shape
# Out:
# torch.Size([1, 21, 512, 1024])

# %%
equi = torch.randn((1,3,512,1024))

# %%
feat_cat = torch.cat((feat_equi, feat_cube), dim = 1).cuda()
feat_cat.shape
# Out:
# torch.Size([1, 42, 512, 1024])

# %%
class Refine(nn.Module):
    def __init__(self):
        super(Refine, self).__init__()
        self.refine_1 = nn.Sequential(
                        nn.Conv2d(42, 32, kernel_size=3, stride=1, padding=1, bias=False),
                        nn.BatchNorm2d(32),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1, bias=False),
                        nn.BatchNorm2d(64),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
                        nn.BatchNorm2d(64),
                        nn.ReLU(inplace=True)
                        )
        self.refine_2 = nn.Sequential(
                        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1, bias=False),
                        nn.BatchNorm2d(128),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1, bias=False),
                        nn.BatchNorm2d(128),
                        nn.ReLU(inplace=True),
                        )
        self.deconv_1 = nn.Sequential(
                        nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, output_padding=0, groups=1, bias=True, dilation=1),
                        nn.BatchNorm2d(64),
                        nn.LeakyReLU(inplace=True),
                        )
        self.deconv_2 = nn.Sequential(
                        nn.ConvTranspose2d(192, 32, kernel_size=4, stride=2, padding=1, output_padding=0, groups=1, bias=True, dilation=1),
                        nn.BatchNorm2d(32),
                        nn.LeakyReLU(inplace=True),
                        )
        self.refine_3 = nn.Sequential(
                        nn.Conv2d(96, 16, kernel_size=3, stride=1, padding=1, bias=False),
                        nn.BatchNorm2d(16),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(16, 21, kernel_size=3, stride=1, padding=1, bias=False)
                        )
        self.bilinear_1 = nn.UpsamplingBilinear2d(size=(256,512))
        self.bilinear_2 = nn.UpsamplingBilinear2d(size=(512,1024))
    def forward(self, inputs):
        x = inputs
        out_1 = self.refine_1(x)
        out_2 = self.refine_2(out_1)
        deconv_out1 = self.deconv_1(out_2)
        up_1 = self.bilinear_1(out_2)
        deconv_out2 = self.deconv_2(torch.cat((deconv_out1, up_1), dim = 1))
        up_2 = self.bilinear_2(out_1)
        out_3 = self.refine_3(torch.cat((deconv_out2, up_2), dim = 1))

        return out_3

# %%
refine_model = Refine().cuda()

# %%
refine = refine_model(feat_cat)

# %%
refine.shape
# Out:
# torch.Size([1, 21, 512, 1024])

# %%
refine
# Out:
# tensor([[[[ 0.4447,  0.7250,  0.4547,  ...,  0.4395,  0.1271, -0.0041],
#           [ 0.2133,  0.3017,  0.4479,  ...,  0.5892,  0.2444, -0.1405],
#           [ 0.2404,  0.5208,  0.4556,  ...,  0.2375,  0.2502, -0.1042],
#           ...,
#           [ 0.4903,  0.3270,  0.5936,  ...,  0.0253,  0.1814,  0.0502],
#           [ 0.2983,  0.4196,  0.4389,  ...,  0.0290,  0.0433, -0.2088],
#           [ 0.2918,  0.1080,  0.2433,  ..., -0.0273, -0.0520, -0.0960]],
#
#          [[-0.0715,  0.0340,  0.1300,  ...,  0.2734, -0.0283,  0.0191],
#           [-0.2055,  0.0406, -0.0135,  ..., -0.1115, -0.2554, -0.0389],
#           [ 0.0036,  0.0234,  0.0876,  ..., -0.1132, -0.0589,  0.1346],
#           ...,
#           [ 0.4731,  0.4156,  0.3527,  ...,  0.4907,  0.2105,  0.1776],
#           [ 0.5284,  0.1091,  0.3086,  ...,  0.1223,  0.0707,  0.2982],
#           [ 0.1869,  0.1058,  0.1558,  ...,  0.0986,  0.1512,  0.0295]],
#
#          [[-0.0485, -0.0502,  0.0602,  ..., -0.0523,  0.1897,  0.0685],
#           [ 0.1236, -0.0082,  0.1158,  ...,  0.1086, -0.0260,  0.1098],
#           [ 0.3220,  0.3826,  0.5006,  ...,  0.0447, -0.0540,  0.1199],
#           ...,
#           [ 0.1576,  0.3406,  0.4049,  ...,  0.6846,  0.5148,  0.3822],
#           [-0.0822,  0.0592,  0.2501,  ...,  0.6023,  0.3997,  0.3588],
#           [-0.0193,  0.3899,  0.1244,  ...,  0.4689,  0.3576,  0.1884]],
#
#          ...,
#
#          [[ 0.0579, -0.3034, -0.4757,  ..., -0.1234, -0.0531, -0.2294],
#           [-0.0306, -0.2475, -0.3180,  ..., -0.1330, -0.1488, -0.0975],
#           [ 0.0136,  0.0646, -0.3249,  ..., -0.0218, -0.0642, -0.2035],
#           ...,
#           [-0.1473,  0.0108,  0.0176,  ..., -0.3009,  0.0275, -0.0170],
#           [-0.1856, -0.0496,  0.1396,  ..., -0.1739, -0.1129,  0.0820],
#           [-0.1652,  0.1115,  0.2487,  ..., -0.2023,  0.0293, -0.0507]],
#
#          [[-0.1416,  0.0305,  0.0776,  ...,  0.1430,  0.0432,  0.1268],
#           [ 0.2285,  0.2863,  0.2316,  ...,  0.1016,  0.1595,  0.0746],
#           [-0.2371,  0.3202,  0.0036,  ...,  0.4885,  0.1281,  0.2447],
#           ...,
#           [-0.1839, -0.1078,  0.2007,  ...,  0.1787,  0.4233,  0.1252],
#           [-0.0649, -0.2783, -0.1521,  ..., -0.0245,  0.4321, -0.0225],
#           [ 0.0853, -0.3509, -0.0474,  ...,  0.1129,  0.1574,  0.0275]],
#
#          [[ 0.1372,  0.1078, -0.0143,  ..., -0.2536, -0.1571, -0.0407],
#           [ 0.1038,  0.1058,  0.1470,  ..., -0.1042, -0.2593, -0.0598],
#           [ 0.0312,  0.2784,  0.1284,  ..., -0.2795, -0.2122,  0.0407],
#           ...,
#           [-0.6243, -0.5856, -1.0256,  ..., -0.9531, -0.8465, -0.6709],
#           [-0.1407, -0.6404, -0.7448,  ..., -0.5140, -0.4026, -0.3948],
#           [-0.1272, -0.1977, -0.4759,  ..., -0.2653, -0.3766, -0.2340]]]],
#        device='cuda:0', grad_fn=<CudnnConvolutionBackward>)

# %%
params = torch.load("./BiFuse_Pretrained.pkl")

# %%
# params = torch.load(name)
model.load_state_dict(params, strict=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ade6400f40dd> in <module>
#       1 # params = torch.load(name)
# ----> 2 model.load_state_dict(params, strict=False)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'load_state_dict'

# %%
keys = list(params.keys())

# %%
keys
# Out:
# ['equi_model.conv1.weight',
#  'equi_model.bn1.weight',
#  'equi_model.bn1.bias',
#  'equi_model.bn1.running_mean',
#  'equi_model.bn1.running_var',
#  'equi_model.bn1.num_batches_tracked',
#  'equi_model.layer1.0.conv1.weight',
#  'equi_model.layer1.0.bn1.weight',
#  'equi_model.layer1.0.bn1.bias',
#  'equi_model.layer1.0.bn1.running_mean',
#  'equi_model.layer1.0.bn1.running_var',
#  'equi_model.layer1.0.bn1.num_batches_tracked',
#  'equi_model.layer1.0.conv2.weight',
#  'equi_model.layer1.0.bn2.weight',
#  'equi_model.layer1.0.bn2.bias',
#  'equi_model.layer1.0.bn2.running_mean',
#  'equi_model.layer1.0.bn2.running_var',
#  'equi_model.layer1.0.bn2.num_batches_tracked',
#  'equi_model.layer1.0.conv3.weight',
#  'equi_model.layer1.0.bn3.weight',
#  'equi_model.layer1.0.bn3.bias',
#  'equi_model.layer1.0.bn3.running_mean',
#  'equi_model.layer1.0.bn3.running_var',
#  'equi_model.layer1.0.bn3.num_batches_tracked',
#  'equi_model.layer1.0.downsample.0.weight',
#  'equi_model.layer1.0.downsample.1.weight',
#  'equi_model.layer1.0.downsample.1.bias',
#  'equi_model.layer1.0.downsample.1.running_mean',
#  'equi_model.layer1.0.downsample.1.running_var',
#  'equi_model.layer1.0.downsample.1.num_batches_tracked',
#  'equi_model.layer1.1.conv1.weight',
#  'equi_model.layer1.1.bn1.weight',
#  'equi_model.layer1.1.bn1.bias',
#  'equi_model.layer1.1.bn1.running_mean',
#  'equi_model.layer1.1.bn1.running_var',
#  'equi_model.layer1.1.bn1.num_batches_tracked',
#  'equi_model.layer1.1.conv2.weight',
#  'equi_model.layer1.1.bn2.weight',
#  'equi_model.layer1.1.bn2.bias',
#  'equi_model.layer1.1.bn2.running_mean',
#  'equi_model.layer1.1.bn2.running_var',
#  'equi_model.layer1.1.bn2.num_batches_tracked',
#  'equi_model.layer1.1.conv3.weight',
#  'equi_model.layer1.1.bn3.weight',
#  'equi_model.layer1.1.bn3.bias',
#  'equi_model.layer1.1.bn3.running_mean',
#  'equi_model.layer1.1.bn3.running_var',
#  'equi_model.layer1.1.bn3.num_batches_tracked',
#  'equi_model.layer1.2.conv1.weight',
#  'equi_model.layer1.2.bn1.weight',
#  'equi_model.layer1.2.bn1.bias',
#  'equi_model.layer1.2.bn1.running_mean',
#  'equi_model.layer1.2.bn1.running_var',
#  'equi_model.layer1.2.bn1.num_batches_tracked',
#  'equi_model.layer1.2.conv2.weight',
#  'equi_model.layer1.2.bn2.weight',
#  'equi_model.layer1.2.bn2.bias',
#  'equi_model.layer1.2.bn2.running_mean',
#  'equi_model.layer1.2.bn2.running_var',
#  'equi_model.layer1.2.bn2.num_batches_tracked',
#  'equi_model.layer1.2.conv3.weight',
#  'equi_model.layer1.2.bn3.weight',
#  'equi_model.layer1.2.bn3.bias',
#  'equi_model.layer1.2.bn3.running_mean',
#  'equi_model.layer1.2.bn3.running_var',
#  'equi_model.layer1.2.bn3.num_batches_tracked',
#  'equi_model.layer2.0.conv1.weight',
#  'equi_model.layer2.0.bn1.weight',
#  'equi_model.layer2.0.bn1.bias',
#  'equi_model.layer2.0.bn1.running_mean',
#  'equi_model.layer2.0.bn1.running_var',
#  'equi_model.layer2.0.bn1.num_batches_tracked',
#  'equi_model.layer2.0.conv2.weight',
#  'equi_model.layer2.0.bn2.weight',
#  'equi_model.layer2.0.bn2.bias',
#  'equi_model.layer2.0.bn2.running_mean',
#  'equi_model.layer2.0.bn2.running_var',
#  'equi_model.layer2.0.bn2.num_batches_tracked',
#  'equi_model.layer2.0.conv3.weight',
#  'equi_model.layer2.0.bn3.weight',
#  'equi_model.layer2.0.bn3.bias',
#  'equi_model.layer2.0.bn3.running_mean',
#  'equi_model.layer2.0.bn3.running_var',
#  'equi_model.layer2.0.bn3.num_batches_tracked',
#  'equi_model.layer2.0.downsample.0.weight',
#  'equi_model.layer2.0.downsample.1.weight',
#  'equi_model.layer2.0.downsample.1.bias',
#  'equi_model.layer2.0.downsample.1.running_mean',
#  'equi_model.layer2.0.downsample.1.running_var',
#  'equi_model.layer2.0.downsample.1.num_batches_tracked',
#  'equi_model.layer2.1.conv1.weight',
#  'equi_model.layer2.1.bn1.weight',
#  'equi_model.layer2.1.bn1.bias',
#  'equi_model.layer2.1.bn1.running_mean',
#  'equi_model.layer2.1.bn1.running_var',
#  'equi_model.layer2.1.bn1.num_batches_tracked',
#  'equi_model.layer2.1.conv2.weight',
#  'equi_model.layer2.1.bn2.weight',
#  'equi_model.layer2.1.bn2.bias',
#  'equi_model.layer2.1.bn2.running_mean',
#  'equi_model.layer2.1.bn2.running_var',
#  'equi_model.layer2.1.bn2.num_batches_tracked',
#  'equi_model.layer2.1.conv3.weight',
#  'equi_model.layer2.1.bn3.weight',
#  'equi_model.layer2.1.bn3.bias',
#  'equi_model.layer2.1.bn3.running_mean',
#  'equi_model.layer2.1.bn3.running_var',
#  'equi_model.layer2.1.bn3.num_batches_tracked',
#  'equi_model.layer2.2.conv1.weight',
#  'equi_model.layer2.2.bn1.weight',
#  'equi_model.layer2.2.bn1.bias',
#  'equi_model.layer2.2.bn1.running_mean',
#  'equi_model.layer2.2.bn1.running_var',
#  'equi_model.layer2.2.bn1.num_batches_tracked',
#  'equi_model.layer2.2.conv2.weight',
#  'equi_model.layer2.2.bn2.weight',
#  'equi_model.layer2.2.bn2.bias',
#  'equi_model.layer2.2.bn2.running_mean',
#  'equi_model.layer2.2.bn2.running_var',
#  'equi_model.layer2.2.bn2.num_batches_tracked',
#  'equi_model.layer2.2.conv3.weight',
#  'equi_model.layer2.2.bn3.weight',
#  'equi_model.layer2.2.bn3.bias',
#  'equi_model.layer2.2.bn3.running_mean',
#  'equi_model.layer2.2.bn3.running_var',
#  'equi_model.layer2.2.bn3.num_batches_tracked',
#  'equi_model.layer2.3.conv1.weight',
#  'equi_model.layer2.3.bn1.weight',
#  'equi_model.layer2.3.bn1.bias',
#  'equi_model.layer2.3.bn1.running_mean',
#  'equi_model.layer2.3.bn1.running_var',
#  'equi_model.layer2.3.bn1.num_batches_tracked',
#  'equi_model.layer2.3.conv2.weight',
#  'equi_model.layer2.3.bn2.weight',
#  'equi_model.layer2.3.bn2.bias',
#  'equi_model.layer2.3.bn2.running_mean',
#  'equi_model.layer2.3.bn2.running_var',
#  'equi_model.layer2.3.bn2.num_batches_tracked',
#  'equi_model.layer2.3.conv3.weight',
#  'equi_model.layer2.3.bn3.weight',
#  'equi_model.layer2.3.bn3.bias',
#  'equi_model.layer2.3.bn3.running_mean',
#  'equi_model.layer2.3.bn3.running_var',
#  'equi_model.layer2.3.bn3.num_batches_tracked',
#  'equi_model.layer3.0.conv1.weight',
#  'equi_model.layer3.0.bn1.weight',
#  'equi_model.layer3.0.bn1.bias',
#  'equi_model.layer3.0.bn1.running_mean',
#  'equi_model.layer3.0.bn1.running_var',
#  'equi_model.layer3.0.bn1.num_batches_tracked',
#  'equi_model.layer3.0.conv2.weight',
#  'equi_model.layer3.0.bn2.weight',
#  'equi_model.layer3.0.bn2.bias',
#  'equi_model.layer3.0.bn2.running_mean',
#  'equi_model.layer3.0.bn2.running_var',
#  'equi_model.layer3.0.bn2.num_batches_tracked',
#  'equi_model.layer3.0.conv3.weight',
#  'equi_model.layer3.0.bn3.weight',
#  'equi_model.layer3.0.bn3.bias',
#  'equi_model.layer3.0.bn3.running_mean',
#  'equi_model.layer3.0.bn3.running_var',
#  'equi_model.layer3.0.bn3.num_batches_tracked',
#  'equi_model.layer3.0.downsample.0.weight',
#  'equi_model.layer3.0.downsample.1.weight',
#  'equi_model.layer3.0.downsample.1.bias',
#  'equi_model.layer3.0.downsample.1.running_mean',
#  'equi_model.layer3.0.downsample.1.running_var',
#  'equi_model.layer3.0.downsample.1.num_batches_tracked',
#  'equi_model.layer3.1.conv1.weight',
#  'equi_model.layer3.1.bn1.weight',
#  'equi_model.layer3.1.bn1.bias',
#  'equi_model.layer3.1.bn1.running_mean',
#  'equi_model.layer3.1.bn1.running_var',
#  'equi_model.layer3.1.bn1.num_batches_tracked',
#  'equi_model.layer3.1.conv2.weight',
#  'equi_model.layer3.1.bn2.weight',
#  'equi_model.layer3.1.bn2.bias',
#  'equi_model.layer3.1.bn2.running_mean',
#  'equi_model.layer3.1.bn2.running_var',
#  'equi_model.layer3.1.bn2.num_batches_tracked',
#  'equi_model.layer3.1.conv3.weight',
#  'equi_model.layer3.1.bn3.weight',
#  'equi_model.layer3.1.bn3.bias',
#  'equi_model.layer3.1.bn3.running_mean',
#  'equi_model.layer3.1.bn3.running_var',
#  'equi_model.layer3.1.bn3.num_batches_tracked',
#  'equi_model.layer3.2.conv1.weight',
#  'equi_model.layer3.2.bn1.weight',
#  'equi_model.layer3.2.bn1.bias',
#  'equi_model.layer3.2.bn1.running_mean',
#  'equi_model.layer3.2.bn1.running_var',
#  'equi_model.layer3.2.bn1.num_batches_tracked',
#  'equi_model.layer3.2.conv2.weight',
#  'equi_model.layer3.2.bn2.weight',
#  'equi_model.layer3.2.bn2.bias',
#  'equi_model.layer3.2.bn2.running_mean',
#  'equi_model.layer3.2.bn2.running_var',
#  'equi_model.layer3.2.bn2.num_batches_tracked',
#  'equi_model.layer3.2.conv3.weight',
#  'equi_model.layer3.2.bn3.weight',
#  'equi_model.layer3.2.bn3.bias',
#  'equi_model.layer3.2.bn3.running_mean',
#  'equi_model.layer3.2.bn3.running_var',
#  'equi_model.layer3.2.bn3.num_batches_tracked',
#  'equi_model.layer3.3.conv1.weight',
#  'equi_model.layer3.3.bn1.weight',
#  'equi_model.layer3.3.bn1.bias',
#  'equi_model.layer3.3.bn1.running_mean',
#  'equi_model.layer3.3.bn1.running_var',
#  'equi_model.layer3.3.bn1.num_batches_tracked',
#  'equi_model.layer3.3.conv2.weight',
#  'equi_model.layer3.3.bn2.weight',
#  'equi_model.layer3.3.bn2.bias',
#  'equi_model.layer3.3.bn2.running_mean',
#  'equi_model.layer3.3.bn2.running_var',
#  'equi_model.layer3.3.bn2.num_batches_tracked',
#  'equi_model.layer3.3.conv3.weight',
#  'equi_model.layer3.3.bn3.weight',
#  'equi_model.layer3.3.bn3.bias',
#  'equi_model.layer3.3.bn3.running_mean',
#  'equi_model.layer3.3.bn3.running_var',
#  'equi_model.layer3.3.bn3.num_batches_tracked',
#  'equi_model.layer3.4.conv1.weight',
#  'equi_model.layer3.4.bn1.weight',
#  'equi_model.layer3.4.bn1.bias',
#  'equi_model.layer3.4.bn1.running_mean',
#  'equi_model.layer3.4.bn1.running_var',
#  'equi_model.layer3.4.bn1.num_batches_tracked',
#  'equi_model.layer3.4.conv2.weight',
#  'equi_model.layer3.4.bn2.weight',
#  'equi_model.layer3.4.bn2.bias',
#  'equi_model.layer3.4.bn2.running_mean',
#  'equi_model.layer3.4.bn2.running_var',
#  'equi_model.layer3.4.bn2.num_batches_tracked',
#  'equi_model.layer3.4.conv3.weight',
#  'equi_model.layer3.4.bn3.weight',
#  'equi_model.layer3.4.bn3.bias',
#  'equi_model.layer3.4.bn3.running_mean',
#  'equi_model.layer3.4.bn3.running_var',
#  'equi_model.layer3.4.bn3.num_batches_tracked',
#  'equi_model.layer3.5.conv1.weight',
#  'equi_model.layer3.5.bn1.weight',
#  'equi_model.layer3.5.bn1.bias',
#  'equi_model.layer3.5.bn1.running_mean',
#  'equi_model.layer3.5.bn1.running_var',
#  'equi_model.layer3.5.bn1.num_batches_tracked',
#  'equi_model.layer3.5.conv2.weight',
#  'equi_model.layer3.5.bn2.weight',
#  'equi_model.layer3.5.bn2.bias',
#  'equi_model.layer3.5.bn2.running_mean',
#  'equi_model.layer3.5.bn2.running_var',
#  'equi_model.layer3.5.bn2.num_batches_tracked',
#  'equi_model.layer3.5.conv3.weight',
#  'equi_model.layer3.5.bn3.weight',
#  'equi_model.layer3.5.bn3.bias',
#  'equi_model.layer3.5.bn3.running_mean',
#  'equi_model.layer3.5.bn3.running_var',
#  'equi_model.layer3.5.bn3.num_batches_tracked',
#  'equi_model.layer4.0.conv1.weight',
#  'equi_model.layer4.0.bn1.weight',
#  'equi_model.layer4.0.bn1.bias',
#  'equi_model.layer4.0.bn1.running_mean',
#  'equi_model.layer4.0.bn1.running_var',
#  'equi_model.layer4.0.bn1.num_batches_tracked',
#  'equi_model.layer4.0.conv2.weight',
#  'equi_model.layer4.0.bn2.weight',
#  'equi_model.layer4.0.bn2.bias',
#  'equi_model.layer4.0.bn2.running_mean',
#  'equi_model.layer4.0.bn2.running_var',
#  'equi_model.layer4.0.bn2.num_batches_tracked',
#  'equi_model.layer4.0.conv3.weight',
#  'equi_model.layer4.0.bn3.weight',
#  'equi_model.layer4.0.bn3.bias',
#  'equi_model.layer4.0.bn3.running_mean',
#  'equi_model.layer4.0.bn3.running_var',
#  'equi_model.layer4.0.bn3.num_batches_tracked',
#  'equi_model.layer4.0.downsample.0.weight',
#  'equi_model.layer4.0.downsample.1.weight',
#  'equi_model.layer4.0.downsample.1.bias',
#  'equi_model.layer4.0.downsample.1.running_mean',
#  'equi_model.layer4.0.downsample.1.running_var',
#  'equi_model.layer4.0.downsample.1.num_batches_tracked',
#  'equi_model.layer4.1.conv1.weight',
#  'equi_model.layer4.1.bn1.weight',
#  'equi_model.layer4.1.bn1.bias',
#  'equi_model.layer4.1.bn1.running_mean',
#  'equi_model.layer4.1.bn1.running_var',
#  'equi_model.layer4.1.bn1.num_batches_tracked',
#  'equi_model.layer4.1.conv2.weight',
#  'equi_model.layer4.1.bn2.weight',
#  'equi_model.layer4.1.bn2.bias',
#  'equi_model.layer4.1.bn2.running_mean',
#  'equi_model.layer4.1.bn2.running_var',
#  'equi_model.layer4.1.bn2.num_batches_tracked',
#  'equi_model.layer4.1.conv3.weight',
#  'equi_model.layer4.1.bn3.weight',
#  'equi_model.layer4.1.bn3.bias',
#  'equi_model.layer4.1.bn3.running_mean',
#  'equi_model.layer4.1.bn3.running_var',
#  'equi_model.layer4.1.bn3.num_batches_tracked',
#  'equi_model.layer4.2.conv1.weight',
#  'equi_model.layer4.2.bn1.weight',
#  'equi_model.layer4.2.bn1.bias',
#  'equi_model.layer4.2.bn1.running_mean',
#  'equi_model.layer4.2.bn1.running_var',
#  'equi_model.layer4.2.bn1.num_batches_tracked',
#  'equi_model.layer4.2.conv2.weight',
#  'equi_model.layer4.2.bn2.weight',
#  'equi_model.layer4.2.bn2.bias',
#  'equi_model.layer4.2.bn2.running_mean',
#  'equi_model.layer4.2.bn2.running_var',
#  'equi_model.layer4.2.bn2.num_batches_tracked',
#  'equi_model.layer4.2.conv3.weight',
#  'equi_model.layer4.2.bn3.weight',
#  'equi_model.layer4.2.bn3.bias',
#  'equi_model.layer4.2.bn3.running_mean',
#  'equi_model.layer4.2.bn3.running_var',
#  'equi_model.layer4.2.bn3.num_batches_tracked',
#  'equi_model.conv2.weight',
#  'equi_model.bn2.weight',
#  'equi_model.bn2.bias',
#  'equi_model.bn2.running_mean',
#  'equi_model.bn2.running_var',
#  'equi_model.bn2.num_batches_tracked',
#  'equi_model.pre1.lst.0.0.weight',
#  'equi_model.pre1.lst.0.0.bias',
#  'equi_model.pre1.lst.0.1.weight',
#  'equi_model.pre1.lst.0.1.bias',
#  'equi_model.pre1.lst.0.1.running_mean',
#  'equi_model.pre1.lst.0.1.running_var',
#  'equi_model.pre1.lst.0.1.num_batches_tracked',
#  'equi_model.pre1.lst.1.0.weight',
#  'equi_model.pre1.lst.1.0.bias',
#  'equi_model.pre1.lst.1.1.weight',
#  'equi_model.pre1.lst.1.1.bias',
#  'equi_model.pre1.lst.1.1.running_mean',
#  'equi_model.pre1.lst.1.1.running_var',
#  'equi_model.pre1.lst.1.1.num_batches_tracked',
#  'equi_model.pre1.lst.2.0.weight',
#  'equi_model.pre1.lst.2.0.bias',
#  'equi_model.pre1.lst.2.1.weight',
#  'equi_model.pre1.lst.2.1.bias',
#  'equi_model.pre1.lst.2.1.running_mean',
#  'equi_model.pre1.lst.2.1.running_var',
#  'equi_model.pre1.lst.2.1.num_batches_tracked',
#  'equi_model.pre1.lst.3.0.weight',
#  'equi_model.pre1.lst.3.0.bias',
#  'equi_model.pre1.lst.3.1.weight',
#  'equi_model.pre1.lst.3.1.bias',
#  'equi_model.pre1.lst.3.1.running_mean',
#  'equi_model.pre1.lst.3.1.running_var',
#  'equi_model.pre1.lst.3.1.num_batches_tracked',
#  'cube_model.conv1.weight',
#  'cube_model.bn1.weight',
#  'cube_model.bn1.bias',
#  'cube_model.bn1.running_mean',
#  'cube_model.bn1.running_var',
#  'cube_model.bn1.num_batches_tracked',
#  'cube_model.layer1.0.conv1.weight',
#  'cube_model.layer1.0.bn1.weight',
#  'cube_model.layer1.0.bn1.bias',
#  'cube_model.layer1.0.bn1.running_mean',
#  'cube_model.layer1.0.bn1.running_var',
#  'cube_model.layer1.0.bn1.num_batches_tracked',
#  'cube_model.layer1.0.conv2.weight',
#  'cube_model.layer1.0.bn2.weight',
#  'cube_model.layer1.0.bn2.bias',
#  'cube_model.layer1.0.bn2.running_mean',
#  'cube_model.layer1.0.bn2.running_var',
#  'cube_model.layer1.0.bn2.num_batches_tracked',
#  'cube_model.layer1.0.conv3.weight',
#  'cube_model.layer1.0.bn3.weight',
#  'cube_model.layer1.0.bn3.bias',
#  'cube_model.layer1.0.bn3.running_mean',
#  'cube_model.layer1.0.bn3.running_var',
#  'cube_model.layer1.0.bn3.num_batches_tracked',
#  'cube_model.layer1.0.downsample.0.weight',
#  'cube_model.layer1.0.downsample.1.weight',
#  'cube_model.layer1.0.downsample.1.bias',
#  'cube_model.layer1.0.downsample.1.running_mean',
#  'cube_model.layer1.0.downsample.1.running_var',
#  'cube_model.layer1.0.downsample.1.num_batches_tracked',
#  'cube_model.layer1.1.conv1.weight',
#  'cube_model.layer1.1.bn1.weight',
#  'cube_model.layer1.1.bn1.bias',
#  'cube_model.layer1.1.bn1.running_mean',
#  'cube_model.layer1.1.bn1.running_var',
#  'cube_model.layer1.1.bn1.num_batches_tracked',
#  'cube_model.layer1.1.conv2.weight',
#  'cube_model.layer1.1.bn2.weight',
#  'cube_model.layer1.1.bn2.bias',
#  'cube_model.layer1.1.bn2.running_mean',
#  'cube_model.layer1.1.bn2.running_var',
#  'cube_model.layer1.1.bn2.num_batches_tracked',
#  'cube_model.layer1.1.conv3.weight',
#  'cube_model.layer1.1.bn3.weight',
#  'cube_model.layer1.1.bn3.bias',
#  'cube_model.layer1.1.bn3.running_mean',
#  'cube_model.layer1.1.bn3.running_var',
#  'cube_model.layer1.1.bn3.num_batches_tracked',
#  'cube_model.layer1.2.conv1.weight',
#  'cube_model.layer1.2.bn1.weight',
#  'cube_model.layer1.2.bn1.bias',
#  'cube_model.layer1.2.bn1.running_mean',
#  'cube_model.layer1.2.bn1.running_var',
#  'cube_model.layer1.2.bn1.num_batches_tracked',
#  'cube_model.layer1.2.conv2.weight',
#  'cube_model.layer1.2.bn2.weight',
#  'cube_model.layer1.2.bn2.bias',
#  'cube_model.layer1.2.bn2.running_mean',
#  'cube_model.layer1.2.bn2.running_var',
#  'cube_model.layer1.2.bn2.num_batches_tracked',
#  'cube_model.layer1.2.conv3.weight',
#  'cube_model.layer1.2.bn3.weight',
#  'cube_model.layer1.2.bn3.bias',
#  'cube_model.layer1.2.bn3.running_mean',
#  'cube_model.layer1.2.bn3.running_var',
#  'cube_model.layer1.2.bn3.num_batches_tracked',
#  'cube_model.layer2.0.conv1.weight',
#  'cube_model.layer2.0.bn1.weight',
#  'cube_model.layer2.0.bn1.bias',
#  'cube_model.layer2.0.bn1.running_mean',
#  'cube_model.layer2.0.bn1.running_var',
#  'cube_model.layer2.0.bn1.num_batches_tracked',
#  'cube_model.layer2.0.conv2.weight',
#  'cube_model.layer2.0.bn2.weight',
#  'cube_model.layer2.0.bn2.bias',
#  'cube_model.layer2.0.bn2.running_mean',
#  'cube_model.layer2.0.bn2.running_var',
#  'cube_model.layer2.0.bn2.num_batches_tracked',
#  'cube_model.layer2.0.conv3.weight',
#  'cube_model.layer2.0.bn3.weight',
#  'cube_model.layer2.0.bn3.bias',
#  'cube_model.layer2.0.bn3.running_mean',
#  'cube_model.layer2.0.bn3.running_var',
#  'cube_model.layer2.0.bn3.num_batches_tracked',
#  'cube_model.layer2.0.downsample.0.weight',
#  'cube_model.layer2.0.downsample.1.weight',
#  'cube_model.layer2.0.downsample.1.bias',
#  'cube_model.layer2.0.downsample.1.running_mean',
#  'cube_model.layer2.0.downsample.1.running_var',
#  'cube_model.layer2.0.downsample.1.num_batches_tracked',
#  'cube_model.layer2.1.conv1.weight',
#  'cube_model.layer2.1.bn1.weight',
#  'cube_model.layer2.1.bn1.bias',
#  'cube_model.layer2.1.bn1.running_mean',
#  'cube_model.layer2.1.bn1.running_var',
#  'cube_model.layer2.1.bn1.num_batches_tracked',
#  'cube_model.layer2.1.conv2.weight',
#  'cube_model.layer2.1.bn2.weight',
#  'cube_model.layer2.1.bn2.bias',
#  'cube_model.layer2.1.bn2.running_mean',
#  'cube_model.layer2.1.bn2.running_var',
#  'cube_model.layer2.1.bn2.num_batches_tracked',
#  'cube_model.layer2.1.conv3.weight',
#  'cube_model.layer2.1.bn3.weight',
#  'cube_model.layer2.1.bn3.bias',
#  'cube_model.layer2.1.bn3.running_mean',
#  'cube_model.layer2.1.bn3.running_var',
#  'cube_model.layer2.1.bn3.num_batches_tracked',
#  'cube_model.layer2.2.conv1.weight',
#  'cube_model.layer2.2.bn1.weight',
#  'cube_model.layer2.2.bn1.bias',
#  'cube_model.layer2.2.bn1.running_mean',
#  'cube_model.layer2.2.bn1.running_var',
#  'cube_model.layer2.2.bn1.num_batches_tracked',
#  'cube_model.layer2.2.conv2.weight',
#  'cube_model.layer2.2.bn2.weight',
#  'cube_model.layer2.2.bn2.bias',
#  'cube_model.layer2.2.bn2.running_mean',
#  'cube_model.layer2.2.bn2.running_var',
#  'cube_model.layer2.2.bn2.num_batches_tracked',
#  'cube_model.layer2.2.conv3.weight',
#  'cube_model.layer2.2.bn3.weight',
#  'cube_model.layer2.2.bn3.bias',
#  'cube_model.layer2.2.bn3.running_mean',
#  'cube_model.layer2.2.bn3.running_var',
#  'cube_model.layer2.2.bn3.num_batches_tracked',
#  'cube_model.layer2.3.conv1.weight',
#  'cube_model.layer2.3.bn1.weight',
#  'cube_model.layer2.3.bn1.bias',
#  'cube_model.layer2.3.bn1.running_mean',
#  'cube_model.layer2.3.bn1.running_var',
#  'cube_model.layer2.3.bn1.num_batches_tracked',
#  'cube_model.layer2.3.conv2.weight',
#  'cube_model.layer2.3.bn2.weight',
#  'cube_model.layer2.3.bn2.bias',
#  'cube_model.layer2.3.bn2.running_mean',
#  'cube_model.layer2.3.bn2.running_var',
#  'cube_model.layer2.3.bn2.num_batches_tracked',
#  'cube_model.layer2.3.conv3.weight',
#  'cube_model.layer2.3.bn3.weight',
#  'cube_model.layer2.3.bn3.bias',
#  'cube_model.layer2.3.bn3.running_mean',
#  'cube_model.layer2.3.bn3.running_var',
#  'cube_model.layer2.3.bn3.num_batches_tracked',
#  'cube_model.layer3.0.conv1.weight',
#  'cube_model.layer3.0.bn1.weight',
#  'cube_model.layer3.0.bn1.bias',
#  'cube_model.layer3.0.bn1.running_mean',
#  'cube_model.layer3.0.bn1.running_var',
#  'cube_model.layer3.0.bn1.num_batches_tracked',
#  'cube_model.layer3.0.conv2.weight',
#  'cube_model.layer3.0.bn2.weight',
#  'cube_model.layer3.0.bn2.bias',
#  'cube_model.layer3.0.bn2.running_mean',
#  'cube_model.layer3.0.bn2.running_var',
#  'cube_model.layer3.0.bn2.num_batches_tracked',
#  'cube_model.layer3.0.conv3.weight',
#  'cube_model.layer3.0.bn3.weight',
#  'cube_model.layer3.0.bn3.bias',
#  'cube_model.layer3.0.bn3.running_mean',
#  'cube_model.layer3.0.bn3.running_var',
#  'cube_model.layer3.0.bn3.num_batches_tracked',
#  'cube_model.layer3.0.downsample.0.weight',
#  'cube_model.layer3.0.downsample.1.weight',
#  'cube_model.layer3.0.downsample.1.bias',
#  'cube_model.layer3.0.downsample.1.running_mean',
#  'cube_model.layer3.0.downsample.1.running_var',
#  'cube_model.layer3.0.downsample.1.num_batches_tracked',
#  'cube_model.layer3.1.conv1.weight',
#  'cube_model.layer3.1.bn1.weight',
#  'cube_model.layer3.1.bn1.bias',
#  'cube_model.layer3.1.bn1.running_mean',
#  'cube_model.layer3.1.bn1.running_var',
#  'cube_model.layer3.1.bn1.num_batches_tracked',
#  'cube_model.layer3.1.conv2.weight',
#  'cube_model.layer3.1.bn2.weight',
#  'cube_model.layer3.1.bn2.bias',
#  'cube_model.layer3.1.bn2.running_mean',
#  'cube_model.layer3.1.bn2.running_var',
#  'cube_model.layer3.1.bn2.num_batches_tracked',
#  'cube_model.layer3.1.conv3.weight',
#  'cube_model.layer3.1.bn3.weight',
#  'cube_model.layer3.1.bn3.bias',
#  'cube_model.layer3.1.bn3.running_mean',
#  'cube_model.layer3.1.bn3.running_var',
#  'cube_model.layer3.1.bn3.num_batches_tracked',
#  'cube_model.layer3.2.conv1.weight',
#  'cube_model.layer3.2.bn1.weight',
#  'cube_model.layer3.2.bn1.bias',
#  'cube_model.layer3.2.bn1.running_mean',
#  'cube_model.layer3.2.bn1.running_var',
#  'cube_model.layer3.2.bn1.num_batches_tracked',
#  'cube_model.layer3.2.conv2.weight',
#  'cube_model.layer3.2.bn2.weight',
#  'cube_model.layer3.2.bn2.bias',
#  'cube_model.layer3.2.bn2.running_mean',
#  'cube_model.layer3.2.bn2.running_var',
#  'cube_model.layer3.2.bn2.num_batches_tracked',
#  'cube_model.layer3.2.conv3.weight',
#  'cube_model.layer3.2.bn3.weight',
#  'cube_model.layer3.2.bn3.bias',
#  'cube_model.layer3.2.bn3.running_mean',
#  'cube_model.layer3.2.bn3.running_var',
#  'cube_model.layer3.2.bn3.num_batches_tracked',
#  'cube_model.layer3.3.conv1.weight',
#  'cube_model.layer3.3.bn1.weight',
#  'cube_model.layer3.3.bn1.bias',
#  'cube_model.layer3.3.bn1.running_mean',
#  'cube_model.layer3.3.bn1.running_var',
#  'cube_model.layer3.3.bn1.num_batches_tracked',
#  'cube_model.layer3.3.conv2.weight',
#  'cube_model.layer3.3.bn2.weight',
#  'cube_model.layer3.3.bn2.bias',
#  'cube_model.layer3.3.bn2.running_mean',
#  'cube_model.layer3.3.bn2.running_var',
#  'cube_model.layer3.3.bn2.num_batches_tracked',
#  'cube_model.layer3.3.conv3.weight',
#  'cube_model.layer3.3.bn3.weight',
#  'cube_model.layer3.3.bn3.bias',
#  'cube_model.layer3.3.bn3.running_mean',
#  'cube_model.layer3.3.bn3.running_var',
#  'cube_model.layer3.3.bn3.num_batches_tracked',
#  'cube_model.layer3.4.conv1.weight',
#  'cube_model.layer3.4.bn1.weight',
#  'cube_model.layer3.4.bn1.bias',
#  'cube_model.layer3.4.bn1.running_mean',
#  'cube_model.layer3.4.bn1.running_var',
#  'cube_model.layer3.4.bn1.num_batches_tracked',
#  'cube_model.layer3.4.conv2.weight',
#  'cube_model.layer3.4.bn2.weight',
#  'cube_model.layer3.4.bn2.bias',
#  'cube_model.layer3.4.bn2.running_mean',
#  'cube_model.layer3.4.bn2.running_var',
#  'cube_model.layer3.4.bn2.num_batches_tracked',
#  'cube_model.layer3.4.conv3.weight',
#  'cube_model.layer3.4.bn3.weight',
#  'cube_model.layer3.4.bn3.bias',
#  'cube_model.layer3.4.bn3.running_mean',
#  'cube_model.layer3.4.bn3.running_var',
#  'cube_model.layer3.4.bn3.num_batches_tracked',
#  'cube_model.layer3.5.conv1.weight',
#  'cube_model.layer3.5.bn1.weight',
#  'cube_model.layer3.5.bn1.bias',
#  'cube_model.layer3.5.bn1.running_mean',
#  'cube_model.layer3.5.bn1.running_var',
#  'cube_model.layer3.5.bn1.num_batches_tracked',
#  'cube_model.layer3.5.conv2.weight',
#  'cube_model.layer3.5.bn2.weight',
#  'cube_model.layer3.5.bn2.bias',
#  'cube_model.layer3.5.bn2.running_mean',
#  'cube_model.layer3.5.bn2.running_var',
#  'cube_model.layer3.5.bn2.num_batches_tracked',
#  'cube_model.layer3.5.conv3.weight',
#  'cube_model.layer3.5.bn3.weight',
#  'cube_model.layer3.5.bn3.bias',
#  'cube_model.layer3.5.bn3.running_mean',
#  'cube_model.layer3.5.bn3.running_var',
#  'cube_model.layer3.5.bn3.num_batches_tracked',
#  'cube_model.layer4.0.conv1.weight',
#  'cube_model.layer4.0.bn1.weight',
#  'cube_model.layer4.0.bn1.bias',
#  'cube_model.layer4.0.bn1.running_mean',
#  'cube_model.layer4.0.bn1.running_var',
#  'cube_model.layer4.0.bn1.num_batches_tracked',
#  'cube_model.layer4.0.conv2.weight',
#  'cube_model.layer4.0.bn2.weight',
#  'cube_model.layer4.0.bn2.bias',
#  'cube_model.layer4.0.bn2.running_mean',
#  'cube_model.layer4.0.bn2.running_var',
#  'cube_model.layer4.0.bn2.num_batches_tracked',
#  'cube_model.layer4.0.conv3.weight',
#  'cube_model.layer4.0.bn3.weight',
#  'cube_model.layer4.0.bn3.bias',
#  'cube_model.layer4.0.bn3.running_mean',
#  'cube_model.layer4.0.bn3.running_var',
#  'cube_model.layer4.0.bn3.num_batches_tracked',
#  'cube_model.layer4.0.downsample.0.weight',
#  'cube_model.layer4.0.downsample.1.weight',
#  'cube_model.layer4.0.downsample.1.bias',
#  'cube_model.layer4.0.downsample.1.running_mean',
#  'cube_model.layer4.0.downsample.1.running_var',
#  'cube_model.layer4.0.downsample.1.num_batches_tracked',
#  'cube_model.layer4.1.conv1.weight',
#  'cube_model.layer4.1.bn1.weight',
#  'cube_model.layer4.1.bn1.bias',
#  'cube_model.layer4.1.bn1.running_mean',
#  'cube_model.layer4.1.bn1.running_var',
#  'cube_model.layer4.1.bn1.num_batches_tracked',
#  'cube_model.layer4.1.conv2.weight',
#  'cube_model.layer4.1.bn2.weight',
#  'cube_model.layer4.1.bn2.bias',
#  'cube_model.layer4.1.bn2.running_mean',
#  'cube_model.layer4.1.bn2.running_var',
#  'cube_model.layer4.1.bn2.num_batches_tracked',
#  'cube_model.layer4.1.conv3.weight',
#  'cube_model.layer4.1.bn3.weight',
#  'cube_model.layer4.1.bn3.bias',
#  'cube_model.layer4.1.bn3.running_mean',
#  'cube_model.layer4.1.bn3.running_var',
#  'cube_model.layer4.1.bn3.num_batches_tracked',
#  'cube_model.layer4.2.conv1.weight',
#  'cube_model.layer4.2.bn1.weight',
#  'cube_model.layer4.2.bn1.bias',
#  'cube_model.layer4.2.bn1.running_mean',
#  'cube_model.layer4.2.bn1.running_var',
#  'cube_model.layer4.2.bn1.num_batches_tracked',
#  'cube_model.layer4.2.conv2.weight',
#  'cube_model.layer4.2.bn2.weight',
#  'cube_model.layer4.2.bn2.bias',
#  'cube_model.layer4.2.bn2.running_mean',
#  'cube_model.layer4.2.bn2.running_var',
#  'cube_model.layer4.2.bn2.num_batches_tracked',
#  'cube_model.layer4.2.conv3.weight',
#  'cube_model.layer4.2.bn3.weight',
#  'cube_model.layer4.2.bn3.bias',
#  'cube_model.layer4.2.bn3.running_mean',
#  'cube_model.layer4.2.bn3.running_var',
#  'cube_model.layer4.2.bn3.num_batches_tracked',
#  'cube_model.conv2.weight',
#  'cube_model.bn2.weight',
#  'cube_model.bn2.bias',
#  'cube_model.bn2.running_mean',
#  'cube_model.bn2.running_var',
#  'cube_model.bn2.num_batches_tracked',
#  'cube_model.pre1.lst.0.0.weight',
#  'cube_model.pre1.lst.0.0.bias',
#  'cube_model.pre1.lst.0.1.weight',
#  'cube_model.pre1.lst.0.1.bias',
#  'cube_model.pre1.lst.0.1.running_mean',
#  'cube_model.pre1.lst.0.1.running_var',
#  'cube_model.pre1.lst.0.1.num_batches_tracked',
#  'cube_model.pre1.lst.1.0.weight',
#  'cube_model.pre1.lst.1.0.bias',
#  'cube_model.pre1.lst.1.1.weight',
#  'cube_model.pre1.lst.1.1.bias',
#  'cube_model.pre1.lst.1.1.running_mean',
#  'cube_model.pre1.lst.1.1.running_var',
#  'cube_model.pre1.lst.1.1.num_batches_tracked',
#  'cube_model.pre1.lst.2.0.weight',
#  'cube_model.pre1.lst.2.0.bias',
#  'cube_model.pre1.lst.2.1.weight',
#  'cube_model.pre1.lst.2.1.bias',
#  'cube_model.pre1.lst.2.1.running_mean',
#  'cube_model.pre1.lst.2.1.running_var',
#  'cube_model.pre1.lst.2.1.num_batches_tracked',
#  'cube_model.pre1.lst.3.0.weight',
#  'cube_model.pre1.lst.3.0.bias',
#  'cube_model.pre1.lst.3.1.weight',
#  'cube_model.pre1.lst.3.1.bias',
#  'cube_model.pre1.lst.3.1.running_mean',
#  'cube_model.pre1.lst.3.1.running_var',
#  'cube_model.pre1.lst.3.1.num_batches_tracked',
#  'refine_model.refine_1.0.weight',
#  'refine_model.refine_1.1.weight',
#  'refine_model.refine_1.1.bias',
#  'refine_model.refine_1.1.running_mean',
#  'refine_model.refine_1.1.running_var',
#  'refine_model.refine_1.1.num_batches_tracked',
#  'refine_model.refine_1.3.weight',
#  'refine_model.refine_1.4.weight',
#  'refine_model.refine_1.4.bias',
#  'refine_model.refine_1.4.running_mean',
#  'refine_model.refine_1.4.running_var',
#  'refine_model.refine_1.4.num_batches_tracked',
#  'refine_model.refine_1.6.weight',
#  'refine_model.refine_1.7.weight',
#  'refine_model.refine_1.7.bias',
#  'refine_model.refine_1.7.running_mean',
#  'refine_model.refine_1.7.running_var',
#  'refine_model.refine_1.7.num_batches_tracked',
#  'refine_model.refine_2.0.weight',
#  'refine_model.refine_2.1.weight',
#  'refine_model.refine_2.1.bias',
#  'refine_model.refine_2.1.running_mean',
#  'refine_model.refine_2.1.running_var',
#  'refine_model.refine_2.1.num_batches_tracked',
#  'refine_model.refine_2.3.weight',
#  'refine_model.refine_2.4.weight',
#  'refine_model.refine_2.4.bias',
#  'refine_model.refine_2.4.running_mean',
#  'refine_model.refine_2.4.running_var',
#  'refine_model.refine_2.4.num_batches_tracked',
#  'refine_model.deconv_1.0.weight',
#  'refine_model.deconv_1.0.bias',
#  'refine_model.deconv_1.1.weight',
#  'refine_model.deconv_1.1.bias',
#  'refine_model.deconv_1.1.running_mean',
#  'refine_model.deconv_1.1.running_var',
#  'refine_model.deconv_1.1.num_batches_tracked',
#  'refine_model.deconv_2.0.weight',
#  'refine_model.deconv_2.0.bias',
#  'refine_model.deconv_2.1.weight',
#  'refine_model.deconv_2.1.bias',
#  'refine_model.deconv_2.1.running_mean',
#  'refine_model.deconv_2.1.running_var',
#  'refine_model.deconv_2.1.num_batches_tracked',
#  'refine_model.refine_3.0.weight',
#  'refine_model.refine_3.1.weight',
#  'refine_model.refine_3.1.bias',
#  'refine_model.refine_3.1.running_mean',
#  'refine_model.refine_3.1.running_var',
#  'refine_model.refine_3.1.num_batches_tracked',
#  'refine_model.refine_3.3.weight',
#  'equi_decoder.layer1.upper_branch.conv1.weight',
#  'equi_decoder.layer1.upper_branch.batchnorm1.weight',
#  'equi_decoder.layer1.upper_branch.batchnorm1.bias',
#  'equi_decoder.layer1.upper_branch.batchnorm1.running_mean',
#  'equi_decoder.layer1.upper_branch.batchnorm1.running_var',
#  'equi_decoder.layer1.upper_branch.batchnorm1.num_batches_tracked',
#  'equi_decoder.layer1.upper_branch.conv2.weight',
#  'equi_decoder.layer1.upper_branch.batchnorm2.weight',
#  'equi_decoder.layer1.upper_branch.batchnorm2.bias',
#  'equi_decoder.layer1.upper_branch.batchnorm2.running_mean',
#  'equi_decoder.layer1.upper_branch.batchnorm2.running_var',
#  'equi_decoder.layer1.upper_branch.batchnorm2.num_batches_tracked',
#  'equi_decoder.layer1.bottom_branch.conv.weight',
#  'equi_decoder.layer1.bottom_branch.batchnorm.weight',
#  'equi_decoder.layer1.bottom_branch.batchnorm.bias',
#  'equi_decoder.layer1.bottom_branch.batchnorm.running_mean',
#  'equi_decoder.layer1.bottom_branch.batchnorm.running_var',
#  'equi_decoder.layer1.bottom_branch.batchnorm.num_batches_tracked',
#  'equi_decoder.layer2.upper_branch.conv1.weight',
#  'equi_decoder.layer2.upper_branch.batchnorm1.weight',
#  'equi_decoder.layer2.upper_branch.batchnorm1.bias',
#  'equi_decoder.layer2.upper_branch.batchnorm1.running_mean',
#  'equi_decoder.layer2.upper_branch.batchnorm1.running_var',
#  'equi_decoder.layer2.upper_branch.batchnorm1.num_batches_tracked',
#  'equi_decoder.layer2.upper_branch.conv2.weight',
#  'equi_decoder.layer2.upper_branch.batchnorm2.weight',
#  'equi_decoder.layer2.upper_branch.batchnorm2.bias',
#  'equi_decoder.layer2.upper_branch.batchnorm2.running_mean',
#  'equi_decoder.layer2.upper_branch.batchnorm2.running_var',
#  'equi_decoder.layer2.upper_branch.batchnorm2.num_batches_tracked',
#  'equi_decoder.layer2.bottom_branch.conv.weight',
#  'equi_decoder.layer2.bottom_branch.batchnorm.weight',
#  'equi_decoder.layer2.bottom_branch.batchnorm.bias',
#  'equi_decoder.layer2.bottom_branch.batchnorm.running_mean',
#  'equi_decoder.layer2.bottom_branch.batchnorm.running_var',
#  'equi_decoder.layer2.bottom_branch.batchnorm.num_batches_tracked',
#  'equi_decoder.layer3.upper_branch.conv1.weight',
#  'equi_decoder.layer3.upper_branch.batchnorm1.weight',
#  'equi_decoder.layer3.upper_branch.batchnorm1.bias',
#  'equi_decoder.layer3.upper_branch.batchnorm1.running_mean',
#  'equi_decoder.layer3.upper_branch.batchnorm1.running_var',
#  'equi_decoder.layer3.upper_branch.batchnorm1.num_batches_tracked',
#  'equi_decoder.layer3.upper_branch.conv2.weight',
#  'equi_decoder.layer3.upper_branch.batchnorm2.weight',
#  'equi_decoder.layer3.upper_branch.batchnorm2.bias',
#  'equi_decoder.layer3.upper_branch.batchnorm2.running_mean',
#  'equi_decoder.layer3.upper_branch.batchnorm2.running_var',
#  'equi_decoder.layer3.upper_branch.batchnorm2.num_batches_tracked',
#  'equi_decoder.layer3.bottom_branch.conv.weight',
#  'equi_decoder.layer3.bottom_branch.batchnorm.weight',
#  'equi_decoder.layer3.bottom_branch.batchnorm.bias',
#  'equi_decoder.layer3.bottom_branch.batchnorm.running_mean',
#  'equi_decoder.layer3.bottom_branch.batchnorm.running_var',
#  'equi_decoder.layer3.bottom_branch.batchnorm.num_batches_tracked',
#  'equi_decoder.layer4.upper_branch.conv1.weight',
#  'equi_decoder.layer4.upper_branch.batchnorm1.weight',
#  'equi_decoder.layer4.upper_branch.batchnorm1.bias',
#  'equi_decoder.layer4.upper_branch.batchnorm1.running_mean',
#  'equi_decoder.layer4.upper_branch.batchnorm1.running_var',
#  'equi_decoder.layer4.upper_branch.batchnorm1.num_batches_tracked',
#  'equi_decoder.layer4.upper_branch.conv2.weight',
#  'equi_decoder.layer4.upper_branch.batchnorm2.weight',
#  'equi_decoder.layer4.upper_branch.batchnorm2.bias',
#  'equi_decoder.layer4.upper_branch.batchnorm2.running_mean',
#  'equi_decoder.layer4.upper_branch.batchnorm2.running_var',
#  'equi_decoder.layer4.upper_branch.batchnorm2.num_batches_tracked',
#  'equi_decoder.layer4.bottom_branch.conv.weight',
#  'equi_decoder.layer4.bottom_branch.batchnorm.weight',
#  'equi_decoder.layer4.bottom_branch.batchnorm.bias',
#  'equi_decoder.layer4.bottom_branch.batchnorm.running_mean',
#  'equi_decoder.layer4.bottom_branch.batchnorm.running_var',
#  'equi_decoder.layer4.bottom_branch.batchnorm.num_batches_tracked',
#  'equi_conv3.0.weight',
#  'cube_decoder.layer1.upper_branch.conv1.weight',
#  'cube_decoder.layer1.upper_branch.batchnorm1.weight',
#  'cube_decoder.layer1.upper_branch.batchnorm1.bias',
#  'cube_decoder.layer1.upper_branch.batchnorm1.running_mean',
#  'cube_decoder.layer1.upper_branch.batchnorm1.running_var',
#  'cube_decoder.layer1.upper_branch.batchnorm1.num_batches_tracked',
#  'cube_decoder.layer1.upper_branch.conv2.weight',
#  'cube_decoder.layer1.upper_branch.batchnorm2.weight',
#  'cube_decoder.layer1.upper_branch.batchnorm2.bias',
#  'cube_decoder.layer1.upper_branch.batchnorm2.running_mean',
#  'cube_decoder.layer1.upper_branch.batchnorm2.running_var',
#  'cube_decoder.layer1.upper_branch.batchnorm2.num_batches_tracked',
#  'cube_decoder.layer1.bottom_branch.conv.weight',
#  'cube_decoder.layer1.bottom_branch.batchnorm.weight',
#  'cube_decoder.layer1.bottom_branch.batchnorm.bias',
#  'cube_decoder.layer1.bottom_branch.batchnorm.running_mean',
#  'cube_decoder.layer1.bottom_branch.batchnorm.running_var',
#  'cube_decoder.layer1.bottom_branch.batchnorm.num_batches_tracked',
#  'cube_decoder.layer2.upper_branch.conv1.weight',
#  'cube_decoder.layer2.upper_branch.batchnorm1.weight',
#  'cube_decoder.layer2.upper_branch.batchnorm1.bias',
#  'cube_decoder.layer2.upper_branch.batchnorm1.running_mean',
#  'cube_decoder.layer2.upper_branch.batchnorm1.running_var',
#  'cube_decoder.layer2.upper_branch.batchnorm1.num_batches_tracked',
#  'cube_decoder.layer2.upper_branch.conv2.weight',
#  'cube_decoder.layer2.upper_branch.batchnorm2.weight',
#  'cube_decoder.layer2.upper_branch.batchnorm2.bias',
#  'cube_decoder.layer2.upper_branch.batchnorm2.running_mean',
#  'cube_decoder.layer2.upper_branch.batchnorm2.running_var',
#  'cube_decoder.layer2.upper_branch.batchnorm2.num_batches_tracked',
#  'cube_decoder.layer2.bottom_branch.conv.weight',
#  'cube_decoder.layer2.bottom_branch.batchnorm.weight',
#  'cube_decoder.layer2.bottom_branch.batchnorm.bias',
#  'cube_decoder.layer2.bottom_branch.batchnorm.running_mean',
#  'cube_decoder.layer2.bottom_branch.batchnorm.running_var',
#  'cube_decoder.layer2.bottom_branch.batchnorm.num_batches_tracked',
#  'cube_decoder.layer3.upper_branch.conv1.weight',
#  'cube_decoder.layer3.upper_branch.batchnorm1.weight',
#  'cube_decoder.layer3.upper_branch.batchnorm1.bias',
#  'cube_decoder.layer3.upper_branch.batchnorm1.running_mean',
#  'cube_decoder.layer3.upper_branch.batchnorm1.running_var',
#  'cube_decoder.layer3.upper_branch.batchnorm1.num_batches_tracked',
#  'cube_decoder.layer3.upper_branch.conv2.weight',
#  'cube_decoder.layer3.upper_branch.batchnorm2.weight',
#  'cube_decoder.layer3.upper_branch.batchnorm2.bias',
#  'cube_decoder.layer3.upper_branch.batchnorm2.running_mean',
#  'cube_decoder.layer3.upper_branch.batchnorm2.running_var',
#  'cube_decoder.layer3.upper_branch.batchnorm2.num_batches_tracked',
#  'cube_decoder.layer3.bottom_branch.conv.weight',
#  'cube_decoder.layer3.bottom_branch.batchnorm.weight',
#  'cube_decoder.layer3.bottom_branch.batchnorm.bias',
#  'cube_decoder.layer3.bottom_branch.batchnorm.running_mean',
#  'cube_decoder.layer3.bottom_branch.batchnorm.running_var',
#  'cube_decoder.layer3.bottom_branch.batchnorm.num_batches_tracked',
#  'cube_decoder.layer4.upper_branch.conv1.weight',
#  'cube_decoder.layer4.upper_branch.batchnorm1.weight',
#  'cube_decoder.layer4.upper_branch.batchnorm1.bias',
#  'cube_decoder.layer4.upper_branch.batchnorm1.running_mean',
#  'cube_decoder.layer4.upper_branch.batchnorm1.running_var',
#  'cube_decoder.layer4.upper_branch.batchnorm1.num_batches_tracked',
#  'cube_decoder.layer4.upper_branch.conv2.weight',
#  'cube_decoder.layer4.upper_branch.batchnorm2.weight',
#  'cube_decoder.layer4.upper_branch.batchnorm2.bias',
#  'cube_decoder.layer4.upper_branch.batchnorm2.running_mean',
#  'cube_decoder.layer4.upper_branch.batchnorm2.running_var',
#  'cube_decoder.layer4.upper_branch.batchnorm2.num_batches_tracked',
#  'cube_decoder.layer4.bottom_branch.conv.weight',
#  'cube_decoder.layer4.bottom_branch.batchnorm.weight',
#  'cube_decoder.layer4.bottom_branch.batchnorm.bias',
#  'cube_decoder.layer4.bottom_branch.batchnorm.running_mean',
#  'cube_decoder.layer4.bottom_branch.batchnorm.running_var',
#  'cube_decoder.layer4.bottom_branch.batchnorm.num_batches_tracked',
#  'cube_conv3.1.weight',
#  'conv_e2c.0.0.weight',
#  'conv_e2c.0.0.bias',
#  'conv_e2c.1.0.weight',
#  'conv_e2c.1.0.bias',
#  'conv_e2c.2.0.weight',
#  'conv_e2c.2.0.bias',
#  'conv_e2c.3.0.weight',
#  'conv_e2c.3.0.bias',
#  'conv_e2c.4.0.weight',
#  'conv_e2c.4.0.bias',
#  'conv_e2c.5.0.weight',
#  'conv_e2c.5.0.bias',
#  'conv_e2c.6.0.weight',
#  'conv_e2c.6.0.bias',
#  'conv_e2c.7.0.weight',
#  'conv_e2c.7.0.bias',
#  'conv_e2c.8.0.weight',
#  'conv_e2c.8.0.bias',
#  'conv_c2e.0.0.weight',
#  'conv_c2e.0.0.bias',
#  'conv_c2e.1.0.weight',
#  'conv_c2e.1.0.bias',
#  'conv_c2e.2.0.weight',
#  'conv_c2e.2.0.bias',
#  'conv_c2e.3.0.weight',
#  'conv_c2e.3.0.bias',
#  'conv_c2e.4.0.weight',
#  'conv_c2e.4.0.bias',
#  'conv_c2e.5.0.weight',
#  'conv_c2e.5.0.bias',
#  'conv_c2e.6.0.weight',
#  'conv_c2e.6.0.bias',
#  'conv_c2e.7.0.weight',
#  'conv_c2e.7.0.bias',
#  'conv_c2e.8.0.weight',
#  'conv_c2e.8.0.bias',
#  'conv_mask.0.0.weight',
#  'conv_mask.0.0.bias',
#  'conv_mask.1.0.weight',
#  'conv_mask.1.0.bias',
#  'conv_mask.2.0.weight',
#  'conv_mask.2.0.bias',
#  'conv_mask.3.0.weight',
#  'conv_mask.3.0.bias',
#  'conv_mask.4.0.weight',
#  'conv_mask.4.0.bias',
#  'conv_mask.5.0.weight',
#  'conv_mask.5.0.bias',
#  'conv_mask.6.0.weight',
#  'conv_mask.6.0.bias',
#  'conv_mask.7.0.weight',
#  'conv_mask.7.0.bias',
#  'conv_mask.8.0.weight',
#  'conv_mask.8.0.bias']

# %%
sub = 'refine'

# %%
for i in keys:
    if sub in i:
        print (i)
# Out:
# refine_model.refine_1.0.weight
# refine_model.refine_1.1.weight
# refine_model.refine_1.1.bias
# refine_model.refine_1.1.running_mean
# refine_model.refine_1.1.running_var
# refine_model.refine_1.1.num_batches_tracked
# refine_model.refine_1.3.weight
# refine_model.refine_1.4.weight
# refine_model.refine_1.4.bias
# refine_model.refine_1.4.running_mean
# refine_model.refine_1.4.running_var
# refine_model.refine_1.4.num_batches_tracked
# refine_model.refine_1.6.weight
# refine_model.refine_1.7.weight
# refine_model.refine_1.7.bias
# refine_model.refine_1.7.running_mean
# refine_model.refine_1.7.running_var
# refine_model.refine_1.7.num_batches_tracked
# refine_model.refine_2.0.weight
# refine_model.refine_2.1.weight
# refine_model.refine_2.1.bias
# refine_model.refine_2.1.running_mean
# refine_model.refine_2.1.running_var
# refine_model.refine_2.1.num_batches_tracked
# refine_model.refine_2.3.weight
# refine_model.refine_2.4.weight
# refine_model.refine_2.4.bias
# refine_model.refine_2.4.running_mean
# refine_model.refine_2.4.running_var
# refine_model.refine_2.4.num_batches_tracked
# refine_model.deconv_1.0.weight
# refine_model.deconv_1.0.bias
# refine_model.deconv_1.1.weight
# refine_model.deconv_1.1.bias
# refine_model.deconv_1.1.running_mean
# refine_model.deconv_1.1.running_var
# refine_model.deconv_1.1.num_batches_tracked
# refine_model.deconv_2.0.weight
# refine_model.deconv_2.0.bias
# refine_model.deconv_2.1.weight
# refine_model.deconv_2.1.bias
# refine_model.deconv_2.1.running_mean
# refine_model.deconv_2.1.running_var
# refine_model.deconv_2.1.num_batches_tracked
# refine_model.refine_3.0.weight
# refine_model.refine_3.1.weight
# refine_model.refine_3.1.bias
# refine_model.refine_3.1.running_mean
# refine_model.refine_3.1.running_var
# refine_model.refine_3.1.num_batches_tracked
# refine_model.refine_3.3.weight

# %%
sub2 = 'dec'

for j in keys:
    if sub2 in j:
        print(j)
# Out:
# refine_model.deconv_1.0.weight
# refine_model.deconv_1.0.bias
# refine_model.deconv_1.1.weight
# refine_model.deconv_1.1.bias
# refine_model.deconv_1.1.running_mean
# refine_model.deconv_1.1.running_var
# refine_model.deconv_1.1.num_batches_tracked
# refine_model.deconv_2.0.weight
# refine_model.deconv_2.0.bias
# refine_model.deconv_2.1.weight
# refine_model.deconv_2.1.bias
# refine_model.deconv_2.1.running_mean
# refine_model.deconv_2.1.running_var
# refine_model.deconv_2.1.num_batches_tracked
# equi_decoder.layer1.upper_branch.conv1.weight
# equi_decoder.layer1.upper_branch.batchnorm1.weight
# equi_decoder.layer1.upper_branch.batchnorm1.bias
# equi_decoder.layer1.upper_branch.batchnorm1.running_mean
# equi_decoder.layer1.upper_branch.batchnorm1.running_var
# equi_decoder.layer1.upper_branch.batchnorm1.num_batches_tracked
# equi_decoder.layer1.upper_branch.conv2.weight
# equi_decoder.layer1.upper_branch.batchnorm2.weight
# equi_decoder.layer1.upper_branch.batchnorm2.bias
# equi_decoder.layer1.upper_branch.batchnorm2.running_mean
# equi_decoder.layer1.upper_branch.batchnorm2.running_var
# equi_decoder.layer1.upper_branch.batchnorm2.num_batches_tracked
# equi_decoder.layer1.bottom_branch.conv.weight
# equi_decoder.layer1.bottom_branch.batchnorm.weight
# equi_decoder.layer1.bottom_branch.batchnorm.bias
# equi_decoder.layer1.bottom_branch.batchnorm.running_mean
# equi_decoder.layer1.bottom_branch.batchnorm.running_var
# equi_decoder.layer1.bottom_branch.batchnorm.num_batches_tracked
# equi_decoder.layer2.upper_branch.conv1.weight
# equi_decoder.layer2.upper_branch.batchnorm1.weight
# equi_decoder.layer2.upper_branch.batchnorm1.bias
# equi_decoder.layer2.upper_branch.batchnorm1.running_mean
# equi_decoder.layer2.upper_branch.batchnorm1.running_var
# equi_decoder.layer2.upper_branch.batchnorm1.num_batches_tracked
# equi_decoder.layer2.upper_branch.conv2.weight
# equi_decoder.layer2.upper_branch.batchnorm2.weight
# equi_decoder.layer2.upper_branch.batchnorm2.bias
# equi_decoder.layer2.upper_branch.batchnorm2.running_mean
# equi_decoder.layer2.upper_branch.batchnorm2.running_var
# equi_decoder.layer2.upper_branch.batchnorm2.num_batches_tracked
# equi_decoder.layer2.bottom_branch.conv.weight
# equi_decoder.layer2.bottom_branch.batchnorm.weight
# equi_decoder.layer2.bottom_branch.batchnorm.bias
# equi_decoder.layer2.bottom_branch.batchnorm.running_mean
# equi_decoder.layer2.bottom_branch.batchnorm.running_var
# equi_decoder.layer2.bottom_branch.batchnorm.num_batches_tracked
# equi_decoder.layer3.upper_branch.conv1.weight
# equi_decoder.layer3.upper_branch.batchnorm1.weight
# equi_decoder.layer3.upper_branch.batchnorm1.bias
# equi_decoder.layer3.upper_branch.batchnorm1.running_mean
# equi_decoder.layer3.upper_branch.batchnorm1.running_var
# equi_decoder.layer3.upper_branch.batchnorm1.num_batches_tracked
# equi_decoder.layer3.upper_branch.conv2.weight
# equi_decoder.layer3.upper_branch.batchnorm2.weight
# equi_decoder.layer3.upper_branch.batchnorm2.bias
# equi_decoder.layer3.upper_branch.batchnorm2.running_mean
# equi_decoder.layer3.upper_branch.batchnorm2.running_var
# equi_decoder.layer3.upper_branch.batchnorm2.num_batches_tracked
# equi_decoder.layer3.bottom_branch.conv.weight
# equi_decoder.layer3.bottom_branch.batchnorm.weight
# equi_decoder.layer3.bottom_branch.batchnorm.bias
# equi_decoder.layer3.bottom_branch.batchnorm.running_mean
# equi_decoder.layer3.bottom_branch.batchnorm.running_var
# equi_decoder.layer3.bottom_branch.batchnorm.num_batches_tracked
# equi_decoder.layer4.upper_branch.conv1.weight
# equi_decoder.layer4.upper_branch.batchnorm1.weight
# equi_decoder.layer4.upper_branch.batchnorm1.bias
# equi_decoder.layer4.upper_branch.batchnorm1.running_mean
# equi_decoder.layer4.upper_branch.batchnorm1.running_var
# equi_decoder.layer4.upper_branch.batchnorm1.num_batches_tracked
# equi_decoder.layer4.upper_branch.conv2.weight
# equi_decoder.layer4.upper_branch.batchnorm2.weight
# equi_decoder.layer4.upper_branch.batchnorm2.bias
# equi_decoder.layer4.upper_branch.batchnorm2.running_mean
# equi_decoder.layer4.upper_branch.batchnorm2.running_var
# equi_decoder.layer4.upper_branch.batchnorm2.num_batches_tracked
# equi_decoder.layer4.bottom_branch.conv.weight
# equi_decoder.layer4.bottom_branch.batchnorm.weight
# equi_decoder.layer4.bottom_branch.batchnorm.bias
# equi_decoder.layer4.bottom_branch.batchnorm.running_mean
# equi_decoder.layer4.bottom_branch.batchnorm.running_var
# equi_decoder.layer4.bottom_branch.batchnorm.num_batches_tracked
# cube_decoder.layer1.upper_branch.conv1.weight
# cube_decoder.layer1.upper_branch.batchnorm1.weight
# cube_decoder.layer1.upper_branch.batchnorm1.bias
# cube_decoder.layer1.upper_branch.batchnorm1.running_mean
# cube_decoder.layer1.upper_branch.batchnorm1.running_var
# cube_decoder.layer1.upper_branch.batchnorm1.num_batches_tracked
# cube_decoder.layer1.upper_branch.conv2.weight
# cube_decoder.layer1.upper_branch.batchnorm2.weight
# cube_decoder.layer1.upper_branch.batchnorm2.bias
# cube_decoder.layer1.upper_branch.batchnorm2.running_mean
# cube_decoder.layer1.upper_branch.batchnorm2.running_var
# cube_decoder.layer1.upper_branch.batchnorm2.num_batches_tracked
# cube_decoder.layer1.bottom_branch.conv.weight
# cube_decoder.layer1.bottom_branch.batchnorm.weight
# cube_decoder.layer1.bottom_branch.batchnorm.bias
# cube_decoder.layer1.bottom_branch.batchnorm.running_mean
# cube_decoder.layer1.bottom_branch.batchnorm.running_var
# cube_decoder.layer1.bottom_branch.batchnorm.num_batches_tracked
# cube_decoder.layer2.upper_branch.conv1.weight
# cube_decoder.layer2.upper_branch.batchnorm1.weight
# cube_decoder.layer2.upper_branch.batchnorm1.bias
# cube_decoder.layer2.upper_branch.batchnorm1.running_mean
# cube_decoder.layer2.upper_branch.batchnorm1.running_var
# cube_decoder.layer2.upper_branch.batchnorm1.num_batches_tracked
# cube_decoder.layer2.upper_branch.conv2.weight
# cube_decoder.layer2.upper_branch.batchnorm2.weight
# cube_decoder.layer2.upper_branch.batchnorm2.bias
# cube_decoder.layer2.upper_branch.batchnorm2.running_mean
# cube_decoder.layer2.upper_branch.batchnorm2.running_var
# cube_decoder.layer2.upper_branch.batchnorm2.num_batches_tracked
# cube_decoder.layer2.bottom_branch.conv.weight
# cube_decoder.layer2.bottom_branch.batchnorm.weight
# cube_decoder.layer2.bottom_branch.batchnorm.bias
# cube_decoder.layer2.bottom_branch.batchnorm.running_mean
# cube_decoder.layer2.bottom_branch.batchnorm.running_var
# cube_decoder.layer2.bottom_branch.batchnorm.num_batches_tracked
# cube_decoder.layer3.upper_branch.conv1.weight
# cube_decoder.layer3.upper_branch.batchnorm1.weight
# cube_decoder.layer3.upper_branch.batchnorm1.bias
# cube_decoder.layer3.upper_branch.batchnorm1.running_mean
# cube_decoder.layer3.upper_branch.batchnorm1.running_var
# cube_decoder.layer3.upper_branch.batchnorm1.num_batches_tracked
# cube_decoder.layer3.upper_branch.conv2.weight
# cube_decoder.layer3.upper_branch.batchnorm2.weight
# cube_decoder.layer3.upper_branch.batchnorm2.bias
# cube_decoder.layer3.upper_branch.batchnorm2.running_mean
# cube_decoder.layer3.upper_branch.batchnorm2.running_var
# cube_decoder.layer3.upper_branch.batchnorm2.num_batches_tracked
# cube_decoder.layer3.bottom_branch.conv.weight
# cube_decoder.layer3.bottom_branch.batchnorm.weight
# cube_decoder.layer3.bottom_branch.batchnorm.bias
# cube_decoder.layer3.bottom_branch.batchnorm.running_mean
# cube_decoder.layer3.bottom_branch.batchnorm.running_var
# cube_decoder.layer3.bottom_branch.batchnorm.num_batches_tracked
# cube_decoder.layer4.upper_branch.conv1.weight
# cube_decoder.layer4.upper_branch.batchnorm1.weight
# cube_decoder.layer4.upper_branch.batchnorm1.bias
# cube_decoder.layer4.upper_branch.batchnorm1.running_mean
# cube_decoder.layer4.upper_branch.batchnorm1.running_var
# cube_decoder.layer4.upper_branch.batchnorm1.num_batches_tracked
# cube_decoder.layer4.upper_branch.conv2.weight
# cube_decoder.layer4.upper_branch.batchnorm2.weight
# cube_decoder.layer4.upper_branch.batchnorm2.bias
# cube_decoder.layer4.upper_branch.batchnorm2.running_mean
# cube_decoder.layer4.upper_branch.batchnorm2.running_var
# cube_decoder.layer4.upper_branch.batchnorm2.num_batches_tracked
# cube_decoder.layer4.bottom_branch.conv.weight
# cube_decoder.layer4.bottom_branch.batchnorm.weight
# cube_decoder.layer4.bottom_branch.batchnorm.bias
# cube_decoder.layer4.bottom_branch.batchnorm.running_mean
# cube_decoder.layer4.bottom_branch.batchnorm.running_var
# cube_decoder.layer4.bottom_branch.batchnorm.num_batches_tracked

# %%
for key in keys:
    if sub in key:
        keys.remove(key)

# %%
for key2 in keys:
    if sub2 in key2:
        keys.remove(key2)

# %%
len(keys)
# Out:
# 853

# %%
len(params)
# Out:
# 953

# %%
for key_ele in list(params.keys()):
    if sub in key_ele:
        del params[key_ele]

# %%
for key_ele2 in list(params.keys()):
    if sub2 in key_ele2:
        del params[key_ele2]

# %%
len(params)
# Out:
# 760

# %%
new_keys = list(params.keys())

# %%
torch.save(params, 'params.pkl')
